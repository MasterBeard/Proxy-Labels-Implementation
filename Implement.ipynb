# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterBeard/Proxy-Labels-Implementation/blob/main/Implement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To ensure the reproducibility of the article, we have provided a notebook code that explains how to use proxy labels to identify investment portfolios with higher precision and a greater number of correct upward signal predictions. The example in the notebook code involves the test results for **Test Set 2** under **Task 1**.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import numpy.polynomial.polynomial as poly

# Define stock and index tickers
stock_tickers = [
    'OKE', 'ENPH', 'UHS', 'DLTR', 'AMZN', 'EFX', 'RSG', 'OXY', 'REGN', 'DECK',
    '^GSPC',  # S&P 500
    '^IXIC',  # NASDAQ Composite
    '^HSI',   # Hang Seng Index
    '^DJI',   # Dow Jones Industrial Average
    '^FCHI',  # CAC 40
    '^GDAXI', # DAX
    '^N225',  # Nikkei 225
    '^KS11',  # KOSPI
    '^STOXX50E'  # EURO STOXX 50
]

# Define date ranges
date_ranges = {
    'train': ("2005-01-01", "2015-01-01"),
    'val': ("2015-01-02", "2019-12-31"),
    'test': ("2020-01-01", "2024-10-31")
}

# Store matrices, labels, and origin for each split
data_splits = {
    split: {
        'matrices_4x4': [],
        'matrices_1st': [],
        'labels4': [],
        'labels1': [],
        'labels2': [],
        'labels3': [],
        'origin': []  # Record the origin (stock or index) of each matrices_4x4
    }
    for split in date_ranges
}

# Window length
window_size = 25
degree = 2

# Fetch and process data for each time period
for split, (start_date, end_date) in date_ranges.items():
    # Download all data (stocks and indices) for the specified date range
    all_data = {ticker: yf.download(ticker, start=start_date, end=end_date, auto_adjust=False) for ticker in stock_tickers}

    # Create first and second derivative matrices for each stock and index
    for ticker, data in all_data.items():
        # Extract required 'Open' and 'Close' data
        open_values = data['Open'].dropna().values
        close_values = data['Close'].dropna().values

        # Build window matrices
        for start in range(len(data) - window_size + 1):
            # Extract each row of data
            open_row = open_values[start:start + window_size]
            close_row = close_values[start:start + window_size]

            # Normalize using the 16th last value of close_row
            normalization_factor = close_row[-16]
            open_row = open_row / normalization_factor
            close_row = close_row / normalization_factor

            # Create an alternating combined array
            combined = np.array([open_row[i // 2] if i % 2 == 0 else close_row[i // 2] for i in range(window_size * 2)])
            matrix_4x4 = combined[:-30].reshape(4, 5, 1)
            matrix_4x5 = combined[-32:].reshape(-1)
            result = [combined[-32], combined[-31], combined[-1]]
            data_splits[split]['matrices_4x4'].append(matrix_4x4)
            data_splits[split]['matrices_1st'].append(matrix_4x5)
            data_splits[split]['origin'].append(ticker)  # Record origin (stock or index)

            # Perform higher-order fitting on combined data
            x = np.arange(len(combined[-4:-1]))
            coeffs = poly.polyfit(x, result, deg=degree)

            # Calculate first derivative
            first_derivative_coeffs = poly.polyder(coeffs)
            first_derivatives = poly.polyval(x, first_derivative_coeffs)

            # Calculate second derivative
            second_derivative_coeffs = poly.polyder(first_derivative_coeffs)
            second_derivatives = poly.polyval(x, second_derivative_coeffs)

            # Generate labels
            label1 = 1 if first_derivatives[0][-1] > 0 else 0
            label2 = 1 if second_derivatives[0][-1] > 0 else 0
            label3 = 1 if close_row[-1] > close_row[-16] else 0
            label4 = [first_derivatives[-1], second_derivatives[-1]]

            data_splits[split]['labels1'].append(label1)
            data_splits[split]['labels2'].append(label2)
            data_splits[split]['labels3'].append(label3)
            data_splits[split]['labels4'].append(label4)

# Convert matrices in each split to NumPy arrays
def convert_to_numpy(split):
    return (
        np.array(data_splits[split]['matrices_4x4']),
        np.array(data_splits[split]['matrices_1st']),
        np.array(data_splits[split]['labels1']),
        np.array(data_splits[split]['labels2']),
        np.array(data_splits[split]['labels3']),
        np.array(data_splits[split]['labels4']),
        np.array(data_splits[split]['origin'])
    )

train_data = convert_to_numpy('train')
val_data = convert_to_numpy('val')
test_data = convert_to_numpy('test')

# Output shapes of each split to check results
print(f"Train 4x4 matrices shape: {train_data[0].shape}")
print(f"Train 1st matrices shape: {train_data[1].shape}")
print(f"Train labels1 shape: {train_data[2].shape}")
print(f"Train origin shape: {train_data[6].shape}")

print(f"Validation 4x4 matrices shape: {val_data[0].shape}")
print(f"Validation 1st matrices shape: {val_data[1].shape}")
print(f"Validation labels1 shape: {val_data[2].shape}")
print(f"Validation origin shape: {val_data[6].shape}")

print(f"Test 4x4 matrices shape: {test_data[0].shape}")
print(f"Test 1st matrices shape: {test_data[1].shape}")
print(f"Test labels1 shape: {test_data[2].shape}")
print(f"Test origin shape: {test_data[6].shape}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Train 4x4 matrices shape: (44871, 4, 5, 1)
# Train 1st matrices shape: (44871, 32)
# Train labels1 shape: (44871,)
# Train origin shape: (44871,)
# Validation 4x4 matrices shape: (23353, 4, 5, 1)
# Validation 1st matrices shape: (23353, 32)
# Validation labels1 shape: (23353,)
# Validation origin shape: (23353,)
# Test 4x4 matrices shape: (22604, 4, 5, 1)
# Test 1st matrices shape: (22604, 32)
# Test labels1 shape: (22604,)
# Test origin shape: (22604,)

# %%
def combine_labels(labels1, labels2, labels3):
    """
    Generate new grouped labels based on the permutations of the three input labels.
    Each combination is uniquely encoded: e.g., (0, 1, 1) → 3.
    """
    # Combine labels into a unique code using weighted sum: labels1 * 4 + labels2 * 2 + labels3 * 1
    combined_labels = labels1 * 4 + labels2 * 2 + labels3 * 1
    return combined_labels

# Regenerate labels for train, validation, and test sets
train_labels = combine_labels(train_data[2], train_data[3], train_data[4])
val_labels = combine_labels(val_data[2], val_data[3], val_data[4])
test_labels = combine_labels(test_data[2], test_data[3], test_data[4])

# Print label distributions to check the combinations
print("Train Labels Distribution:", np.unique(train_labels, return_counts=True))
print("Validation Labels Distribution:", np.unique(val_labels, return_counts=True))
print("Test Labels Distribution:", np.unique(test_labels, return_counts=True))
# Out:
# Train Labels Distribution: (array([0, 1, 2, 5, 6, 7]), array([17051,   559,   859,  1096,   438, 24868]))
# Validation Labels Distribution: (array([0, 1, 2, 5, 6, 7]), array([ 9210,   263,   480,   560,   264, 12576]))
# Test Labels Distribution: (array([0, 1, 2, 5, 6, 7]), array([ 9010,   241,   446,   492,   225, 12190]))

# %%
import tensorflow as tf
from tensorflow import keras

# Build MLP model
model1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(4, 5, 1)),  # Flatten (4, 5, 1) into (20,)
    tf.keras.layers.Dense(units=64, activation='relu'),  # First Dense layer
    tf.keras.layers.Dense(units=64, activation='relu'),  # Second Dense layer
    tf.keras.layers.Dense(units=8, activation='softmax')  # 8-class classification
])

# Compile the model
model1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',  # Suitable for integer labels
    metrics=['accuracy']
)

# Train the model
history1 = model1.fit(
    train_data[0], train_labels,  # Training data (inputs, labels)
    epochs=300,
    batch_size=128,
    validation_data=(val_data[0], val_labels),  # Validation data
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)],
    verbose=1
)

# Save model1
model1.save('modeltaskmlp1.h5')
# Out:
# Epoch 1/300
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5350 - loss: 1.0502 - val_accuracy: 0.5385 - val_loss: 0.9795
# Epoch 2/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5562 - loss: 0.9645 - val_accuracy: 0.5386 - val_loss: 0.9755
# Epoch 3/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5545 - loss: 0.9628 - val_accuracy: 0.5385 - val_loss: 0.9729
# Epoch 4/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5601 - loss: 0.9605 - val_accuracy: 0.5385 - val_loss: 0.9728
# Epoch 5/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5522 - loss: 0.9692 - val_accuracy: 0.5385 - val_loss: 0.9729
# Epoch 6/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5547 - loss: 0.9648 - val_accuracy: 0.5385 - val_loss: 0.9736
# Epoch 7/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5501 - loss: 0.9660 - val_accuracy: 0.5385 - val_loss: 0.9718
# Epoch 8/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5545 - loss: 0.9641 - val_accuracy: 0.5385 - val_loss: 0.9757
# Epoch 9/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5509 - loss: 0.9613 - val_accuracy: 0.5385 - val_loss: 0.9731
# Epoch 10/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5555 - loss: 0.9637 - val_accuracy: 0.5385 - val_loss: 0.9718
# Epoch 11/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5524 - loss: 0.9666 - val_accuracy: 0.5385 - val_loss: 0.9734
# Epoch 12/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5557 - loss: 0.9660 - val_accuracy: 0.5385 - val_loss: 0.9712
# Epoch 13/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5532 - loss: 0.9637 - val_accuracy: 0.5385 - val_loss: 0.9757
# Epoch 14/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5517 - loss: 0.9643 - val_accuracy: 0.5385 - val_loss: 0.9706
# Epoch 15/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5535 - loss: 0.9630 - val_accuracy: 0.5385 - val_loss: 0.9747
# Epoch 16/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5575 - loss: 0.9582 - val_accuracy: 0.5385 - val_loss: 0.9710
# Epoch 17/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5525 - loss: 0.9621 - val_accuracy: 0.5385 - val_loss: 0.9719
# Epoch 18/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5516 - loss: 0.9674 - val_accuracy: 0.5385 - val_loss: 0.9719
# Epoch 19/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5545 - loss: 0.9602 - val_accuracy: 0.5385 - val_loss: 0.9791
# Epoch 20/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5549 - loss: 0.9590 - val_accuracy: 0.5385 - val_loss: 0.9696
# Epoch 21/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5553 - loss: 0.9546 - val_accuracy: 0.5386 - val_loss: 0.9702
# Epoch 22/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5527 - loss: 0.9635 - val_accuracy: 0.5386 - val_loss: 0.9750
# Epoch 23/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5563 - loss: 0.9600 - val_accuracy: 0.5386 - val_loss: 0.9672
# Epoch 24/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5514 - loss: 0.9628 - val_accuracy: 0.5386 - val_loss: 0.9671
# Epoch 25/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5554 - loss: 0.9545 - val_accuracy: 0.5386 - val_loss: 0.9698
# Epoch 26/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5570 - loss: 0.9496 - val_accuracy: 0.5386 - val_loss: 0.9665
# Epoch 27/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5572 - loss: 0.9535 - val_accuracy: 0.5386 - val_loss: 0.9672
# Epoch 28/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5565 - loss: 0.9507 - val_accuracy: 0.5386 - val_loss: 0.9632
# Epoch 29/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5559 - loss: 0.9535 - val_accuracy: 0.5386 - val_loss: 0.9635
# Epoch 30/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5520 - loss: 0.9506 - val_accuracy: 0.5385 - val_loss: 0.9633
# Epoch 31/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5551 - loss: 0.9536 - val_accuracy: 0.5385 - val_loss: 0.9595
# Epoch 32/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5522 - loss: 0.9413 - val_accuracy: 0.5384 - val_loss: 0.9653
# Epoch 33/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5582 - loss: 0.9448 - val_accuracy: 0.5385 - val_loss: 0.9564
# Epoch 34/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5514 - loss: 0.9471 - val_accuracy: 0.5383 - val_loss: 0.9575
# Epoch 35/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5492 - loss: 0.9482 - val_accuracy: 0.5384 - val_loss: 0.9522
# Epoch 36/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5543 - loss: 0.9409 - val_accuracy: 0.5389 - val_loss: 0.9507
# Epoch 37/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5544 - loss: 0.9437 - val_accuracy: 0.5385 - val_loss: 0.9549
# Epoch 38/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5535 - loss: 0.9432 - val_accuracy: 0.5386 - val_loss: 0.9569
# Epoch 39/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5527 - loss: 0.9353 - val_accuracy: 0.5386 - val_loss: 0.9499
# Epoch 40/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5537 - loss: 0.9375 - val_accuracy: 0.5384 - val_loss: 0.9636
# Epoch 41/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5571 - loss: 0.9303 - val_accuracy: 0.5392 - val_loss: 0.9519
# Epoch 42/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5581 - loss: 0.9315 - val_accuracy: 0.5386 - val_loss: 0.9550
# Epoch 43/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5552 - loss: 0.9381 - val_accuracy: 0.5384 - val_loss: 0.9465
# Epoch 44/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5568 - loss: 0.9257 - val_accuracy: 0.5388 - val_loss: 0.9422
# Epoch 45/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5578 - loss: 0.9318 - val_accuracy: 0.5386 - val_loss: 0.9588
# Epoch 46/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5577 - loss: 0.9321 - val_accuracy: 0.5387 - val_loss: 0.9405
# Epoch 47/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5548 - loss: 0.9295 - val_accuracy: 0.5386 - val_loss: 0.9490
# Epoch 48/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5541 - loss: 0.9337 - val_accuracy: 0.5385 - val_loss: 0.9438
# Epoch 49/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5534 - loss: 0.9311 - val_accuracy: 0.5391 - val_loss: 0.9414
# Epoch 50/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5613 - loss: 0.9237 - val_accuracy: 0.5394 - val_loss: 0.9452
# Epoch 51/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5546 - loss: 0.9293 - val_accuracy: 0.5396 - val_loss: 0.9433
# Epoch 52/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5569 - loss: 0.9241 - val_accuracy: 0.5400 - val_loss: 0.9417
# Epoch 53/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5542 - loss: 0.9317 - val_accuracy: 0.5385 - val_loss: 0.9398
# Epoch 54/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5548 - loss: 0.9287 - val_accuracy: 0.5393 - val_loss: 0.9400
# Epoch 55/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5545 - loss: 0.9229 - val_accuracy: 0.5398 - val_loss: 0.9381
# Epoch 56/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5569 - loss: 0.9183 - val_accuracy: 0.5385 - val_loss: 0.9441
# Epoch 57/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5576 - loss: 0.9214 - val_accuracy: 0.5393 - val_loss: 0.9337
# Epoch 58/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5534 - loss: 0.9338 - val_accuracy: 0.5389 - val_loss: 0.9359
# Epoch 59/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5554 - loss: 0.9217 - val_accuracy: 0.5409 - val_loss: 0.9413
# Epoch 60/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5576 - loss: 0.9224 - val_accuracy: 0.5384 - val_loss: 0.9337
# Epoch 61/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5544 - loss: 0.9245 - val_accuracy: 0.5385 - val_loss: 0.9465
# Epoch 62/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5581 - loss: 0.9215 - val_accuracy: 0.5401 - val_loss: 0.9387
# Epoch 63/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5548 - loss: 0.9197 - val_accuracy: 0.5394 - val_loss: 0.9331
# Epoch 64/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5597 - loss: 0.9200 - val_accuracy: 0.5395 - val_loss: 0.9301
# Epoch 65/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5562 - loss: 0.9271 - val_accuracy: 0.5398 - val_loss: 0.9319
# Epoch 66/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5555 - loss: 0.9230 - val_accuracy: 0.5394 - val_loss: 0.9410
# Epoch 67/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5578 - loss: 0.9203 - val_accuracy: 0.5393 - val_loss: 0.9348
# Epoch 68/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5537 - loss: 0.9189 - val_accuracy: 0.5406 - val_loss: 0.9381
# Epoch 69/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5614 - loss: 0.9141 - val_accuracy: 0.5392 - val_loss: 0.9301
# Epoch 70/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5568 - loss: 0.9174 - val_accuracy: 0.5393 - val_loss: 0.9293
# Epoch 71/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5600 - loss: 0.9149 - val_accuracy: 0.5395 - val_loss: 0.9311
# Epoch 72/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5553 - loss: 0.9171 - val_accuracy: 0.5393 - val_loss: 0.9365
# Epoch 73/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5573 - loss: 0.9213 - val_accuracy: 0.5395 - val_loss: 0.9283
# Epoch 74/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5564 - loss: 0.9155 - val_accuracy: 0.5391 - val_loss: 0.9333
# Epoch 75/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5526 - loss: 0.9243 - val_accuracy: 0.5398 - val_loss: 0.9322
# Epoch 76/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5543 - loss: 0.9241 - val_accuracy: 0.5393 - val_loss: 0.9305
# Epoch 77/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5612 - loss: 0.9158 - val_accuracy: 0.5400 - val_loss: 0.9379
# Epoch 78/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5587 - loss: 0.9230 - val_accuracy: 0.5401 - val_loss: 0.9268
# Epoch 79/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5547 - loss: 0.9216 - val_accuracy: 0.5392 - val_loss: 0.9310
# Epoch 80/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5524 - loss: 0.9225 - val_accuracy: 0.5403 - val_loss: 0.9309
# Epoch 81/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5545 - loss: 0.9177 - val_accuracy: 0.5399 - val_loss: 0.9279
# Epoch 82/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5574 - loss: 0.9103 - val_accuracy: 0.5398 - val_loss: 0.9258
# Epoch 83/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5566 - loss: 0.9125 - val_accuracy: 0.5398 - val_loss: 0.9342
# Epoch 84/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5542 - loss: 0.9221 - val_accuracy: 0.5392 - val_loss: 0.9338
# Epoch 85/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5535 - loss: 0.9180 - val_accuracy: 0.5392 - val_loss: 0.9266
# Epoch 86/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5584 - loss: 0.9142 - val_accuracy: 0.5408 - val_loss: 0.9278
# Epoch 87/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5517 - loss: 0.9161 - val_accuracy: 0.5394 - val_loss: 0.9338
# Epoch 88/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5536 - loss: 0.9140 - val_accuracy: 0.5413 - val_loss: 0.9279
# Epoch 89/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5552 - loss: 0.9185 - val_accuracy: 0.5390 - val_loss: 0.9400
# Epoch 90/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5572 - loss: 0.9120 - val_accuracy: 0.5395 - val_loss: 0.9274
# Epoch 91/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5552 - loss: 0.9145 - val_accuracy: 0.5393 - val_loss: 0.9308
# Epoch 92/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5552 - loss: 0.9150 - val_accuracy: 0.5405 - val_loss: 0.9271
# Epoch 93/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5576 - loss: 0.9118 - val_accuracy: 0.5401 - val_loss: 0.9284
# Epoch 94/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5577 - loss: 0.9159 - val_accuracy: 0.5397 - val_loss: 0.9253
# Epoch 95/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5546 - loss: 0.9133 - val_accuracy: 0.5394 - val_loss: 0.9321
# Epoch 96/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5544 - loss: 0.9145 - val_accuracy: 0.5397 - val_loss: 0.9242
# Epoch 97/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5537 - loss: 0.9168 - val_accuracy: 0.5394 - val_loss: 0.9284
# Epoch 98/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5575 - loss: 0.9233 - val_accuracy: 0.5394 - val_loss: 0.9247
# Epoch 99/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5582 - loss: 0.9174 - val_accuracy: 0.5409 - val_loss: 0.9288
# Epoch 100/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5541 - loss: 0.9157 - val_accuracy: 0.5390 - val_loss: 0.9329
# Epoch 101/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5564 - loss: 0.9153 - val_accuracy: 0.5392 - val_loss: 0.9379
# Epoch 102/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5600 - loss: 0.9115 - val_accuracy: 0.5393 - val_loss: 0.9382
# Epoch 103/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5548 - loss: 0.9137 - val_accuracy: 0.5395 - val_loss: 0.9249
# Epoch 104/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5578 - loss: 0.9120 - val_accuracy: 0.5393 - val_loss: 0.9236
# Epoch 105/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5556 - loss: 0.9112 - val_accuracy: 0.5407 - val_loss: 0.9317
# Epoch 106/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5546 - loss: 0.9129 - val_accuracy: 0.5407 - val_loss: 0.9220
# Epoch 107/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5577 - loss: 0.9132 - val_accuracy: 0.5416 - val_loss: 0.9402
# Epoch 108/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5570 - loss: 0.9159 - val_accuracy: 0.5406 - val_loss: 0.9376
# Epoch 109/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5505 - loss: 0.9125 - val_accuracy: 0.5391 - val_loss: 0.9407
# Epoch 110/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5561 - loss: 0.9204 - val_accuracy: 0.5391 - val_loss: 0.9250
# Epoch 111/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5573 - loss: 0.9073 - val_accuracy: 0.5393 - val_loss: 0.9292
# Epoch 112/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5577 - loss: 0.9088 - val_accuracy: 0.5390 - val_loss: 0.9849
# Epoch 113/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5547 - loss: 0.9181 - val_accuracy: 0.5401 - val_loss: 0.9243
# Epoch 114/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5564 - loss: 0.9140 - val_accuracy: 0.5407 - val_loss: 0.9258
# Epoch 115/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5550 - loss: 0.9153 - val_accuracy: 0.5393 - val_loss: 0.9350
# Epoch 116/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5535 - loss: 0.9172 - val_accuracy: 0.5387 - val_loss: 0.9683
# Epoch 117/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5552 - loss: 0.9177 - val_accuracy: 0.5407 - val_loss: 0.9253
# Epoch 118/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5609 - loss: 0.9046 - val_accuracy: 0.5387 - val_loss: 0.9397
# Epoch 119/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5560 - loss: 0.9148 - val_accuracy: 0.5389 - val_loss: 0.9301
# Epoch 120/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5597 - loss: 0.9069 - val_accuracy: 0.5407 - val_loss: 0.9203
# Epoch 121/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5562 - loss: 0.9190 - val_accuracy: 0.5393 - val_loss: 0.9231
# Epoch 122/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5570 - loss: 0.9080 - val_accuracy: 0.5420 - val_loss: 0.9252
# Epoch 123/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5546 - loss: 0.9112 - val_accuracy: 0.5407 - val_loss: 0.9291
# Epoch 124/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5574 - loss: 0.9057 - val_accuracy: 0.5412 - val_loss: 0.9468
# Epoch 125/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5577 - loss: 0.9059 - val_accuracy: 0.5415 - val_loss: 0.9275
# Epoch 126/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5532 - loss: 0.9150 - val_accuracy: 0.5406 - val_loss: 0.9230
# Epoch 127/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5512 - loss: 0.9218 - val_accuracy: 0.5395 - val_loss: 0.9238
# Epoch 128/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5590 - loss: 0.9033 - val_accuracy: 0.5405 - val_loss: 0.9198
# Epoch 129/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5577 - loss: 0.9050 - val_accuracy: 0.5383 - val_loss: 0.9464
# Epoch 130/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5579 - loss: 0.9111 - val_accuracy: 0.5397 - val_loss: 0.9203
# Epoch 131/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5558 - loss: 0.9066 - val_accuracy: 0.5414 - val_loss: 0.9341
# Epoch 132/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5566 - loss: 0.9154 - val_accuracy: 0.5427 - val_loss: 0.9963
# Epoch 133/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5553 - loss: 0.9177 - val_accuracy: 0.5396 - val_loss: 0.9220
# Epoch 134/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5546 - loss: 0.9134 - val_accuracy: 0.5391 - val_loss: 0.9238
# Epoch 135/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5531 - loss: 0.9116 - val_accuracy: 0.5392 - val_loss: 0.9218
# Epoch 136/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5591 - loss: 0.9036 - val_accuracy: 0.5402 - val_loss: 0.9332
# Epoch 137/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5639 - loss: 0.9010 - val_accuracy: 0.5392 - val_loss: 0.9448
# Epoch 138/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5588 - loss: 0.9090 - val_accuracy: 0.5411 - val_loss: 0.9482
# Epoch 139/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5568 - loss: 0.9108 - val_accuracy: 0.5395 - val_loss: 0.9234
# Epoch 140/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5574 - loss: 0.9115 - val_accuracy: 0.5414 - val_loss: 0.9265
# Epoch 141/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5530 - loss: 0.9063 - val_accuracy: 0.5393 - val_loss: 0.9205
# Epoch 142/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5541 - loss: 0.9106 - val_accuracy: 0.5400 - val_loss: 0.9234
# Epoch 143/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5601 - loss: 0.9025 - val_accuracy: 0.5412 - val_loss: 0.9359
# Epoch 144/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5538 - loss: 0.9144 - val_accuracy: 0.5392 - val_loss: 0.9192
# Epoch 145/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5594 - loss: 0.9081 - val_accuracy: 0.5387 - val_loss: 0.9771
# Epoch 146/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5539 - loss: 0.9206 - val_accuracy: 0.5404 - val_loss: 0.9202
# Epoch 147/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5563 - loss: 0.9082 - val_accuracy: 0.5398 - val_loss: 0.9205
# Epoch 148/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5586 - loss: 0.9120 - val_accuracy: 0.5391 - val_loss: 0.9316
# Epoch 149/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5572 - loss: 0.9086 - val_accuracy: 0.5396 - val_loss: 0.9195
# Epoch 150/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5554 - loss: 0.9095 - val_accuracy: 0.5393 - val_loss: 0.9300
# Epoch 151/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5598 - loss: 0.9123 - val_accuracy: 0.5406 - val_loss: 0.9207
# Epoch 152/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5579 - loss: 0.9034 - val_accuracy: 0.5417 - val_loss: 0.9442
# Epoch 153/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5562 - loss: 0.9153 - val_accuracy: 0.5384 - val_loss: 0.9451
# Epoch 154/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5529 - loss: 0.9157 - val_accuracy: 0.5401 - val_loss: 0.9225
# Epoch 155/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5569 - loss: 0.9090 - val_accuracy: 0.5393 - val_loss: 0.9215
# Epoch 156/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5596 - loss: 0.9044 - val_accuracy: 0.5393 - val_loss: 0.9202
# Epoch 157/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5588 - loss: 0.9029 - val_accuracy: 0.5419 - val_loss: 0.9607
# Epoch 158/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5560 - loss: 0.9050 - val_accuracy: 0.5396 - val_loss: 0.9271
# Epoch 159/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5549 - loss: 0.9143 - val_accuracy: 0.5416 - val_loss: 0.9385
# Epoch 160/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5528 - loss: 0.9106 - val_accuracy: 0.5396 - val_loss: 0.9200
# Epoch 161/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5541 - loss: 0.9122 - val_accuracy: 0.5390 - val_loss: 0.9187
# Epoch 162/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5569 - loss: 0.9131 - val_accuracy: 0.5403 - val_loss: 0.9222
# Epoch 163/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5572 - loss: 0.9134 - val_accuracy: 0.5416 - val_loss: 0.9269
# Epoch 164/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5536 - loss: 0.9112 - val_accuracy: 0.5386 - val_loss: 0.9472
# Epoch 165/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5579 - loss: 0.9097 - val_accuracy: 0.5392 - val_loss: 0.9244
# Epoch 166/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5550 - loss: 0.9077 - val_accuracy: 0.5386 - val_loss: 0.9277
# Epoch 167/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5564 - loss: 0.9110 - val_accuracy: 0.5402 - val_loss: 0.9216
# Epoch 168/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5572 - loss: 0.9089 - val_accuracy: 0.5407 - val_loss: 0.9273
# Epoch 169/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5574 - loss: 0.9119 - val_accuracy: 0.5393 - val_loss: 0.9200
# Epoch 170/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5568 - loss: 0.9084 - val_accuracy: 0.5404 - val_loss: 0.9291
# Epoch 171/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5599 - loss: 0.9002 - val_accuracy: 0.5394 - val_loss: 0.9176
# Epoch 172/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5552 - loss: 0.9096 - val_accuracy: 0.5406 - val_loss: 0.9358
# Epoch 173/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5570 - loss: 0.9074 - val_accuracy: 0.5386 - val_loss: 0.9495
# Epoch 174/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5530 - loss: 0.9097 - val_accuracy: 0.5401 - val_loss: 0.9221
# Epoch 175/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5563 - loss: 0.9089 - val_accuracy: 0.5402 - val_loss: 0.9235
# Epoch 176/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5580 - loss: 0.9063 - val_accuracy: 0.5401 - val_loss: 0.9279
# Epoch 177/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5521 - loss: 0.9134 - val_accuracy: 0.5400 - val_loss: 0.9278
# Epoch 178/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5573 - loss: 0.9167 - val_accuracy: 0.5404 - val_loss: 0.9192
# Epoch 179/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5611 - loss: 0.9020 - val_accuracy: 0.5391 - val_loss: 0.9196
# Epoch 180/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5567 - loss: 0.9033 - val_accuracy: 0.5408 - val_loss: 0.9244
# Epoch 181/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5548 - loss: 0.9095 - val_accuracy: 0.5402 - val_loss: 0.9180
# Epoch 182/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5547 - loss: 0.9077 - val_accuracy: 0.5404 - val_loss: 0.9168
# Epoch 183/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5594 - loss: 0.9086 - val_accuracy: 0.5402 - val_loss: 0.9177
# Epoch 184/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5587 - loss: 0.9079 - val_accuracy: 0.5389 - val_loss: 0.9438
# Epoch 185/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5602 - loss: 0.9133 - val_accuracy: 0.5395 - val_loss: 0.9180
# Epoch 186/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5581 - loss: 0.9031 - val_accuracy: 0.5402 - val_loss: 0.9185
# Epoch 187/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5593 - loss: 0.9091 - val_accuracy: 0.5389 - val_loss: 0.9613
# Epoch 188/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5524 - loss: 0.9138 - val_accuracy: 0.5403 - val_loss: 0.9174
# Epoch 189/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5575 - loss: 0.9090 - val_accuracy: 0.5416 - val_loss: 0.9302
# Epoch 190/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5574 - loss: 0.9053 - val_accuracy: 0.5401 - val_loss: 0.9322
# Epoch 191/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5529 - loss: 0.9124 - val_accuracy: 0.5394 - val_loss: 0.9196
# Epoch 192/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5544 - loss: 0.9036 - val_accuracy: 0.5395 - val_loss: 0.9207
# Epoch 193/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5636 - loss: 0.9031 - val_accuracy: 0.5423 - val_loss: 0.9566
# Epoch 194/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5571 - loss: 0.9063 - val_accuracy: 0.5390 - val_loss: 0.9215
# Epoch 195/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5561 - loss: 0.9022 - val_accuracy: 0.5398 - val_loss: 0.9303
# Epoch 196/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5553 - loss: 0.9081 - val_accuracy: 0.5403 - val_loss: 0.9260
# Epoch 197/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5568 - loss: 0.9050 - val_accuracy: 0.5389 - val_loss: 0.9201
# Epoch 198/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5598 - loss: 0.9055 - val_accuracy: 0.5395 - val_loss: 0.9331
# Epoch 199/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5561 - loss: 0.9114 - val_accuracy: 0.5403 - val_loss: 0.9323
# Epoch 200/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5536 - loss: 0.9150 - val_accuracy: 0.5392 - val_loss: 0.9218
# Epoch 201/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5552 - loss: 0.9083 - val_accuracy: 0.5404 - val_loss: 0.9163
# Epoch 202/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5601 - loss: 0.9149 - val_accuracy: 0.5401 - val_loss: 0.9173
# Epoch 203/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5571 - loss: 0.9091 - val_accuracy: 0.5404 - val_loss: 0.9202
# Epoch 204/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5519 - loss: 0.9085 - val_accuracy: 0.5400 - val_loss: 0.9641
# Epoch 205/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5564 - loss: 0.9098 - val_accuracy: 0.5386 - val_loss: 0.9365
# Epoch 206/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5604 - loss: 0.9014 - val_accuracy: 0.5404 - val_loss: 0.9175
# Epoch 207/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5564 - loss: 0.9023 - val_accuracy: 0.5389 - val_loss: 0.9577
# Epoch 208/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5580 - loss: 0.9102 - val_accuracy: 0.5397 - val_loss: 0.9189
# Epoch 209/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5573 - loss: 0.9042 - val_accuracy: 0.5401 - val_loss: 0.9164
# Epoch 210/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5563 - loss: 0.9014 - val_accuracy: 0.5390 - val_loss: 0.9199
# Epoch 211/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5640 - loss: 0.9065 - val_accuracy: 0.5401 - val_loss: 0.9229
# Epoch 212/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5565 - loss: 0.9094 - val_accuracy: 0.5402 - val_loss: 0.9183
# Epoch 213/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5534 - loss: 0.9112 - val_accuracy: 0.5406 - val_loss: 0.9211
# Epoch 214/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5581 - loss: 0.9090 - val_accuracy: 0.5398 - val_loss: 0.9195
# Epoch 215/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5593 - loss: 0.9048 - val_accuracy: 0.5404 - val_loss: 0.9212
# Epoch 216/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5555 - loss: 0.9099 - val_accuracy: 0.5399 - val_loss: 0.9301
# Epoch 217/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5572 - loss: 0.9080 - val_accuracy: 0.5394 - val_loss: 0.9327
# Epoch 218/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5569 - loss: 0.9027 - val_accuracy: 0.5412 - val_loss: 0.9176
# Epoch 219/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5553 - loss: 0.9132 - val_accuracy: 0.5387 - val_loss: 0.9678
# Epoch 220/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5540 - loss: 0.9081 - val_accuracy: 0.5383 - val_loss: 0.9209
# Epoch 221/300
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5524 - loss: 0.9104 - val_accuracy: 0.5389 - val_loss: 0.9237
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import zipfile
import os
from google.colab import drive

# Mount Google Drive to access files
drive.mount('/content/drive')

# Set file paths
zip_file_path = '/content/drive/My Drive/SP500_data2020-2024.zip'  # Replace with the path to the file in Google Drive
output_dir = '/content/SP500_data2020-2024'  # Extract to Colab working directory

# Extract files
os.makedirs(output_dir, exist_ok=True)
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(output_dir)

print("Files extracted to:", output_dir)

# List all CSV files in the extracted directory
csv_files = sorted([f for f in os.listdir(output_dir) if f.endswith('.csv')])
print(f"Found {len(csv_files)} CSV files.")
print("Sample files:", csv_files[:5])  # Print the first 5 files alphabetically

import pandas as pd

# Read all CSV files into a dictionary
sp500_data = {}
for csv_file in csv_files:
    symbol = csv_file.replace('.csv', '')  # Extract the stock symbol
    file_path = os.path.join(output_dir, csv_file)
    sp500_data[symbol] = pd.read_csv(file_path)

# Filter symbols to keep only those with the most common data length
def filter_symbols_by_most_common_length(sp500_data):
    # Calculate the length of data for each symbol
    lengths = {symbol: len(data) for symbol, data in sp500_data.items()}

    # Count the frequency of each length
    length_counts = pd.Series(lengths).value_counts()

    # Find the most common length
    most_common_length = length_counts.idxmax()
    print(f"Most common length: {most_common_length}, Count: {length_counts.max()}")

    # Filter symbols with the most common length
    filtered_symbols = [symbol for symbol, length in lengths.items() if length == most_common_length]

    # Return filtered data and the most common length
    filtered_data = {symbol: sp500_data[symbol] for symbol in filtered_symbols}
    return filtered_data, most_common_length

# Filter the data
filtered_sp500_data, most_common_length = filter_symbols_by_most_common_length(sp500_data)

# Check the filtered result
print(f"Filtered data count: {len(filtered_sp500_data)}")

# Window length
window_size = 25
degree = 2

# Data collection
data_set = {'matrices_4x4': [], 'labels1': [], 'labels2': [], 'labels3': []}

# Create matrices and labels for each stock
for index_name, data in filtered_sp500_data.items():
    # Ensure 'Open' and 'Close' columns are numeric
    data['Open'] = pd.to_numeric(data['Open'], errors='coerce')
    data['Close'] = pd.to_numeric(data['Close'], errors='coerce')

    # Extract 'Open' and 'Close' values, skipping the first two rows
    open_values = data['Open'].values[2:]
    close_values = data['Close'].values[2:]

    # Build window matrices
    num_samples = len(data) - window_size + 1
    for start in range(num_samples - 2):  # Iterate through all data points
        # Extract window data
        open_row = open_values[start:start + window_size]
        close_row = close_values[start:start + window_size]

        # Normalize using the 16th last value of close_row
        normalization_factor = close_row[-16]
        open_row = open_row / normalization_factor
        close_row = close_row / normalization_factor

        # Create an alternating combined array
        combined = np.array([open_row[i // 2] if i % 2 == 0 else close_row[i // 2] for i in range(window_size * 2)])
        matrix_4x4 = combined[:-30].reshape(4, 5, 1)
        result = [combined[-32], combined[-31], combined[-1]]

        # Perform higher-order fitting on combined data
        x = np.arange(len(combined[-4:-1]))
        coeffs = poly.polyfit(x, result, deg=degree)

        # Calculate first and second derivatives
        first_derivative_coeffs = poly.polyder(coeffs)
        first_derivatives = poly.polyval(x, first_derivative_coeffs)
        second_derivative_coeffs = poly.polyder(first_derivative_coeffs)
        second_derivatives = poly.polyval(x, second_derivative_coeffs)

        # Calculate labels
        label1 = 1 if first_derivatives[-1] > 0 else 0
        label2 = 1 if second_derivatives[-1] > 0 else 0
        label3 = 1 if close_row[-1] > close_row[-16] else 0

        # Add to the unified data collection
        data_set['matrices_4x4'].append(matrix_4x4)
        data_set['labels1'].append(label1)
        data_set['labels2'].append(label2)
        data_set['labels3'].append(label3)

# Convert data to NumPy arrays
matrices_4x4 = np.array(data_set['matrices_4x4'])
labels1 = np.array(data_set['labels1'])
labels2 = np.array(data_set['labels2'])
labels3 = np.array(data_set['labels3'])

# Output results for verification
print(f"4x4 matrices shape: {matrices_4x4.shape}")
print(f"Labels1 shape: {labels1.shape}")
print(f"Labels2 shape: {labels2.shape}")
print(f"Labels3 shape: {labels3.shape}")
# Out:
# Mounted at /content/drive
# Files extracted to: /content/SP500_data2020-2024
# Found 501 CSV files.
# Sample files: ['A.csv', 'AAPL.csv', 'ABBV.csv', 'ABNB.csv', 'ABT.csv']
# Most common length: 1239, Count: 489
# Filtered data count: 489
# 4x4 matrices shape: (593157, 4, 5, 1)
# Labels1 shape: (593157,)
# Labels2 shape: (593157,)
# Labels3 shape: (593157,)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score

# Get model prediction probabilities
predictions2_pro = model1.predict(matrices_4x4)

# Get predicted labels
predicted_classes = np.argmax(predictions2_pro, axis=1)

# Get the total number of classes
num_classes = predictions2_pro.shape[1]

# Initialize the final prediction array
final_predictions = np.full(predictions2_pro.shape[0], -1)  # Initialize with -1 to indicate unclassified

# Define the threshold range
thresholds = np.arange(0.5, 0.95, 0.05)  # From 0.5 to 0.95 with a step of 0.05

# Iterate over each threshold for evaluation
for threshold in thresholds:
    # Reset the prediction array
    final_predictions[:] = -1

    # Iterate over each class label to process samples predicted as that class
    for class_label in range(num_classes):
        # Find indices of samples predicted as the current class
        class_indices = np.where(predicted_classes == class_label)[0]

        if len(class_indices) > 0:
            # Get probabilities for these samples
            class_probs = predictions2_pro[class_indices, class_label]

            # Filter indices where probability exceeds the threshold
            selected_indices = class_indices[class_probs >= threshold]

            # Mark as odd (1) or even (0)
            odd_or_even = 1 if class_label % 2 == 1 else 0
            final_predictions[selected_indices] = odd_or_even

    # Filter out valid predictions
    valid_indices = final_predictions != -1
    filtered_final_predictions = final_predictions[valid_indices]
    filtered_true_labels = labels3[valid_indices]  # Corresponding true labels

    # Calculate accuracy
    accuracy = np.mean(filtered_final_predictions == filtered_true_labels)

    # Create confusion matrix
    cm = confusion_matrix(filtered_true_labels, filtered_final_predictions, labels=[0, 1])

    # Calculate Precision
    tp = cm[1, 1]  # True Positives
    fp = cm[0, 1]  # False Positives
    precision = tp / (tp + fp) if (tp + fp) != 0 else 0  # Handle division by zero

    # Calculate Recall
    fn = cm[1, 0]  # False Negatives
    recall = tp / (tp + fn) if (tp + fn) != 0 else 0  # Handle division by zero

    # Calculate F1 Score
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

    # Print results
    print(f"Threshold: {threshold:.2f}")
    print(f"Accuracy: {accuracy:.2%}")
    print(f"Precision (TP / (TP + FP)): {precision:.2%}")
    print(f"Recall (TP / (TP + FN)): {recall:.2%}")
    print(f"F1 Score: {f1:.2%}")
    print(f"Confusion Matrix:\n{cm}\n")
# Out:
# 18537/18537 ━━━━━━━━━━━━━━━━━━━━ 22s 1ms/step
# Threshold: 0.50
# Accuracy: 55.18%
# Precision (TP / (TP + FP)): 55.26%
# Recall (TP / (TP + FN)): 99.44%
# F1 Score: 71.04%
# Confusion Matrix:
# [[   957 215846]
#  [  1503 266636]]
#
# Threshold: 0.55
# Accuracy: 55.29%
# Precision (TP / (TP + FP)): 55.33%
# Recall (TP / (TP + FN)): 99.75%
# F1 Score: 71.18%
# Confusion Matrix:
# [[   287 159375]
#  [   488 197372]]
#
# Threshold: 0.60
# Accuracy: 62.39%
# Precision (TP / (TP + FP)): 63.46%
# Recall (TP / (TP + FN)): 95.94%
# F1 Score: 76.39%
# Confusion Matrix:
# [[  86 1959]
#  [ 144 3402]]
#
# Threshold: 0.65
# Accuracy: 70.91%
# Precision (TP / (TP + FP)): 71.19%
# Recall (TP / (TP + FN)): 98.79%
# F1 Score: 82.75%
# Confusion Matrix:
# [[  31  758]
#  [  23 1873]]
#
# Threshold: 0.70
# Accuracy: 73.55%
# Precision (TP / (TP + FP)): 73.54%
# Recall (TP / (TP + FN)): 99.87%
# F1 Score: 84.71%
# Confusion Matrix:
# [[   6  549]
#  [   2 1526]]
#
# Threshold: 0.75
# Accuracy: 75.39%
# Precision (TP / (TP + FP)): 75.36%
# Recall (TP / (TP + FN)): 100.00%
# F1 Score: 85.95%
# Confusion Matrix:
# [[   2  406]
#  [   0 1242]]
#
# Threshold: 0.80
# Accuracy: 77.72%
# Precision (TP / (TP + FP)): 77.72%
# Recall (TP / (TP + FN)): 100.00%
# F1 Score: 87.46%
# Confusion Matrix:
# [[  0 285]
#  [  0 994]]
#
# Threshold: 0.85
# Accuracy: 78.15%
# Precision (TP / (TP + FP)): 78.15%
# Recall (TP / (TP + FN)): 100.00%
# F1 Score: 87.74%
# Confusion Matrix:
# [[  0 208]
#  [  0 744]]
#
# Threshold: 0.90
# Accuracy: 77.95%
# Precision (TP / (TP + FP)): 77.95%
# Recall (TP / (TP + FN)): 100.00%
# F1 Score: 87.61%
# Confusion Matrix:
# [[  0 142]
#  [  0 502]]

# %%
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# **Ensure input data is in 2D format**
X_train = train_data[0].reshape(train_data[0].shape[0], -1)
X_test = matrices_4x4.reshape(matrices_4x4.shape[0], -1)

# **Ensure labels are integers**
y_train = train_data[4].astype(int)
y_test = labels3.astype(int)

# **Initialize models**
models = {
    "GradientBoostingClassifier": GradientBoostingClassifier(random_state=42, n_estimators=100, verbose=1),
    "RandomForestClassifier": RandomForestClassifier(random_state=42, n_estimators=100, verbose=1),
    "LogisticRegression": LogisticRegression(random_state=42, max_iter=500, verbose=1),
    "XGBRegressor": XGBRegressor(random_state=42, n_estimators=100, verbosity=1)
}

# **Set threshold range**
thresholds = np.arange(0.5, 0.95, 0.05)  # From 0.5 to 0.95 with a step of 0.05

# **Store results for all models**
results = {}

# **Iterate over each model**
for model_name, model in models.items():
    print(f"\nTraining {model_name}...")

    # **Train the model**
    model.fit(X_train, y_train)

    # **Get predictions**
    if model_name == "XGBRegressor":
        # XGBRegressor outputs continuous values, need to convert to classification results
        y_pred_test = model.predict(X_test)
        prob_positive = y_pred_test  # Probability of positive class
        prob_negative = 1 - y_pred_test  # Probability of negative class
    else:
        # Other models output probabilities
        y_proba_test = model.predict_proba(X_test)[:, 1]  # Probability of positive class
        prob_positive = y_proba_test  # Probability of positive class
        prob_negative = 1 - y_proba_test  # Probability of negative class

    # **Store results for different thresholds**
    results[model_name] = {}

    # **Iterate over each threshold**
    for threshold in thresholds:
        # **Initialize final prediction array**
        final_predictions = np.full(prob_positive.shape[0], -1)  # -1 indicates unclassified

        # **Filter positive and negative classes**
        positive_indices = prob_positive >= threshold  # Positive class probability >= threshold
        negative_indices = prob_negative >= threshold  # Negative class probability >= threshold

        # **Classify based on conditions**
        final_predictions[positive_indices] = 1  # Positive class
        final_predictions[negative_indices] = 0  # Negative class

        # **Filter out valid predictions**
        valid_indices = final_predictions != -1
        filtered_final_predictions = final_predictions[valid_indices]
        filtered_true_labels = y_test[valid_indices]  # True labels

        # **Skip current threshold if no valid predictions**
        if len(filtered_final_predictions) == 0:
            print(f"Threshold: {threshold:.2f} | No valid predictions.")
            continue

        # **Calculate accuracy**
        accuracy = np.mean(filtered_final_predictions == filtered_true_labels)

        # **Create confusion matrix**
        cm = confusion_matrix(filtered_true_labels, filtered_final_predictions, labels=[0, 1])

        # **Calculate precision, avoiding division by zero**
        tp = cm[1, 1]  # True Positives
        fp = cm[0, 1]  # False Positives
        precision = tp / (tp + fp) if (tp + fp) != 0 else 0

        # **Calculate recall, avoiding division by zero**
        fn = cm[1, 0]  # False Negatives
        recall = tp / (tp + fn) if (tp + fn) != 0 else 0

        # **Calculate F1 Score, avoiding division by zero**
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

        # **Store results**
        results[model_name][threshold] = {
            "Accuracy": accuracy,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Confusion Matrix": cm
        }

        # **Print results**
        print(f"Model: {model_name} | Threshold: {threshold:.2f}")
        print(f"  Accuracy: {accuracy:.2%}")
        print(f"  Precision: {precision:.2%}")
        print(f"  Recall: {recall:.2%}")
        print(f"  F1 Score: {f1:.2%}")
        print(f"  Confusion Matrix:\n{cm}\n")
# Out:
# Training GradientBoostingClassifier...
#       Iter       Train Loss   Remaining Time
#          1           1.3524           51.93s
#          2           1.3519           51.94s
#          3           1.3515           51.41s
#          4           1.3512           50.98s
#          5           1.3508           50.55s
#          6           1.3504           49.90s
#          7           1.3501           49.41s
#          8           1.3497           48.80s
#          9           1.3495           48.23s
#         10           1.3491           47.79s
#         20           1.3468           44.76s
#         30           1.3449           39.35s
#         40           1.3428           33.12s
#         50           1.3407           28.30s
#         60           1.3389           22.34s
#         70           1.3370           16.93s
#         80           1.3352           11.23s
#         90           1.3335            5.58s
#        100           1.3319            0.00s
# Model: GradientBoostingClassifier | Threshold: 0.50
#   Accuracy: 54.87%
#   Precision: 55.17%
#   Recall: 97.88%
#   F1 Score: 70.57%
#   Confusion Matrix:
# [[  4545 260744]
#  [  6956 320912]]
#
# Model: GradientBoostingClassifier | Threshold: 0.55
#   Accuracy: 54.92%
#   Precision: 55.05%
#   Recall: 99.10%
#   F1 Score: 70.78%
#   Confusion Matrix:
# [[  1751 243699]
#  [  2702 298450]]
#
# Model: GradientBoostingClassifier | Threshold: 0.60
#   Accuracy: 54.38%
#   Precision: 54.53%
#   Recall: 98.89%
#   F1 Score: 70.29%
#   Confusion Matrix:
# [[   779  86784]
#  [  1168 104062]]
#
# Model: GradientBoostingClassifier | Threshold: 0.65
#   Accuracy: 59.35%
#   Precision: 62.12%
#   Recall: 87.98%
#   F1 Score: 72.82%
#   Confusion Matrix:
# [[ 382 2589]
#  [ 580 4245]]
#
# Model: GradientBoostingClassifier | Threshold: 0.70
#   Accuracy: 64.40%
#   Precision: 67.38%
#   Recall: 89.88%
#   F1 Score: 77.02%
#   Confusion Matrix:
# [[ 194 1178]
#  [ 274 2433]]
#
# Model: GradientBoostingClassifier | Threshold: 0.75
#   Accuracy: 67.80%
#   Precision: 69.42%
#   Recall: 94.29%
#   F1 Score: 79.97%
#   Confusion Matrix:
# [[ 101  807]
#  [ 111 1832]]
#
# Model: GradientBoostingClassifier | Threshold: 0.80
#   Accuracy: 70.55%
#   Precision: 71.85%
#   Recall: 96.20%
#   F1 Score: 82.26%
#   Confusion Matrix:
# [[  36  427]
#  [  43 1090]]
#
# Model: GradientBoostingClassifier | Threshold: 0.85
#   Accuracy: 75.15%
#   Precision: 75.30%
#   Recall: 99.21%
#   F1 Score: 85.62%
#   Confusion Matrix:
# [[  6 124]
#  [  3 378]]
#
# Model: GradientBoostingClassifier | Threshold: 0.90
#   Accuracy: 53.49%
#   Precision: 54.76%
#   Recall: 95.83%
#   F1 Score: 69.70%
#   Confusion Matrix:
# [[ 0 19]
#  [ 1 23]]
#
#
# Training RandomForestClassifier...
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    8.1s
# Model: RandomForestClassifier | Threshold: 0.50
#   Accuracy: 53.16%
#   Precision: 55.11%
#   Recall: 82.28%
#   F1 Score: 66.01%
#   Confusion Matrix:
# [[ 45560 219729]
#  [ 58096 269772]]
#
# Model: RandomForestClassifier | Threshold: 0.55
#   Accuracy: 54.14%
#   Precision: 55.07%
#   Recall: 91.72%
#   F1 Score: 68.82%
#   Confusion Matrix:
# [[ 15040 175233]
#  [ 19387 214757]]
#
# Model: RandomForestClassifier | Threshold: 0.60
#   Accuracy: 54.72%
#   Precision: 55.08%
#   Recall: 96.74%
#   F1 Score: 70.20%
#   Confusion Matrix:
# [[  2927  91697]
#  [  3785 112438]]
#
# Model: RandomForestClassifier | Threshold: 0.65
#   Accuracy: 54.94%
#   Precision: 55.12%
#   Recall: 98.24%
#   F1 Score: 70.62%
#   Confusion Matrix:
# [[  670 37579]
#  [  827 46151]]
#
# Model: RandomForestClassifier | Threshold: 0.70
#   Accuracy: 55.41%
#   Precision: 55.54%
#   Recall: 98.66%
#   F1 Score: 71.07%
#   Confusion Matrix:
# [[  155 10760]
#  [  183 13442]]
#
# Model: RandomForestClassifier | Threshold: 0.75
#   Accuracy: 56.87%
#   Precision: 56.96%
#   Recall: 98.83%
#   F1 Score: 72.27%
#   Confusion Matrix:
# [[  37 2363]
#  [  37 3127]]
#
# Model: RandomForestClassifier | Threshold: 0.80
#   Accuracy: 59.91%
#   Precision: 60.01%
#   Recall: 99.32%
#   F1 Score: 74.82%
#   Confusion Matrix:
# [[  5 585]
#  [  6 878]]
#
# Model: RandomForestClassifier | Threshold: 0.85
#   Accuracy: 61.06%
#   Precision: 60.86%
#   Recall: 100.00%
#   F1 Score: 75.67%
#   Confusion Matrix:
# [[  3 236]
#  [  0 367]]
#
# Model: RandomForestClassifier | Threshold: 0.90
#   Accuracy: 60.51%
#   Precision: 60.51%
#   Recall: 100.00%
#   F1 Score: 75.40%
#   Confusion Matrix:
# [[  0 109]
#  [  0 167]]
#
#
# Training LogisticRegression...
# Model: LogisticRegression | Threshold: 0.50
#   Accuracy: 55.28%
#   Precision: 55.28%
#   Recall: 100.00%
#   F1 Score: 71.20%
#   Confusion Matrix:
# [[     0 265289]
#  [     0 327868]]
#
# Model: LogisticRegression | Threshold: 0.55
#   Accuracy: 55.28%
#   Precision: 55.28%
#   Recall: 100.00%
#   F1 Score: 71.20%
#   Confusion Matrix:
# [[     0 265227]
#  [     0 327796]]
#
# Model: LogisticRegression | Threshold: 0.60
#   Accuracy: 56.33%
#   Precision: 56.33%
#   Recall: 100.00%
#   F1 Score: 72.06%
#   Confusion Matrix:
# [[    0 26010]
#  [    0 33547]]
#
# Model: LogisticRegression | Threshold: 0.65
#   Accuracy: 75.61%
#   Precision: 75.61%
#   Recall: 100.00%
#   F1 Score: 86.11%
#   Confusion Matrix:
# [[  0 240]
#  [  0 744]]
#
# Model: LogisticRegression | Threshold: 0.70
#   Accuracy: 74.16%
#   Precision: 74.16%
#   Recall: 100.00%
#   F1 Score: 85.16%
#   Confusion Matrix:
# [[  0  54]
#  [  0 155]]
#
# Model: LogisticRegression | Threshold: 0.75
#   Accuracy: 65.38%
#   Precision: 65.38%
#   Recall: 100.00%
#   F1 Score: 79.07%
#   Confusion Matrix:
# [[ 0 27]
#  [ 0 51]]
#
# Model: LogisticRegression | Threshold: 0.80
#   Accuracy: 70.00%
#   Precision: 70.00%
#   Recall: 100.00%
#   F1 Score: 82.35%
#   Confusion Matrix:
# [[ 0  9]
#  [ 0 21]]
#
# Model: LogisticRegression | Threshold: 0.85
#   Accuracy: 90.00%
#   Precision: 90.00%
#   Recall: 100.00%
#   F1 Score: 94.74%
#   Confusion Matrix:
# [[0 1]
#  [0 9]]
#
# Model: LogisticRegression | Threshold: 0.90
#   Accuracy: 100.00%
#   Precision: 100.00%
#   Recall: 100.00%
#   F1 Score: 100.00%
#   Confusion Matrix:
# [[0 0]
#  [0 5]]
#
#
# Training XGBRegressor...
# Model: XGBRegressor | Threshold: 0.50
#   Accuracy: 52.66%
#   Precision: 55.10%
#   Recall: 77.56%
#   F1 Score: 64.43%
#   Confusion Matrix:
# [[ 58080 207209]
#  [ 73575 254293]]
#
# Model: XGBRegressor | Threshold: 0.55
#   Accuracy: 53.19%
#   Precision: 55.16%
#   Recall: 82.59%
#   F1 Score: 66.14%
#   Confusion Matrix:
# [[ 34423 171515]
#  [ 44468 210985]]
#
# Model: XGBRegressor | Threshold: 0.60
#   Accuracy: 53.64%
#   Precision: 55.42%
#   Recall: 85.43%
#   F1 Score: 67.23%
#   Confusion Matrix:
# [[ 19840 124414]
#  [ 26372 154652]]
#
# Model: XGBRegressor | Threshold: 0.65
#   Accuracy: 54.03%
#   Precision: 55.80%
#   Recall: 86.36%
#   F1 Score: 67.79%
#   Confusion Matrix:
# [[11394 77406]
#  [15432 97711]]
#
# Model: XGBRegressor | Threshold: 0.70
#   Accuracy: 54.38%
#   Precision: 56.39%
#   Recall: 85.83%
#   F1 Score: 68.06%
#   Confusion Matrix:
# [[ 6511 42404]
#  [ 9054 54828]]
#
# Model: XGBRegressor | Threshold: 0.75
#   Accuracy: 54.70%
#   Precision: 57.28%
#   Recall: 84.14%
#   F1 Score: 68.16%
#   Confusion Matrix:
# [[ 3689 21456]
#  [ 5423 28771]]
#
# Model: XGBRegressor | Threshold: 0.80
#   Accuracy: 54.60%
#   Precision: 58.16%
#   Recall: 81.04%
#   F1 Score: 67.72%
#   Confusion Matrix:
# [[ 2137 10475]
#  [ 3407 14559]]
#
# Model: XGBRegressor | Threshold: 0.85
#   Accuracy: 54.90%
#   Precision: 59.52%
#   Recall: 77.91%
#   F1 Score: 67.49%
#   Confusion Matrix:
# [[1253 4932]
#  [2056 7253]]
#
# Model: XGBRegressor | Threshold: 0.90
#   Accuracy: 54.47%
#   Precision: 60.53%
#   Recall: 73.51%
#   F1 Score: 66.39%
#   Confusion Matrix:
# [[ 758 2341]
#  [1294 3590]]
